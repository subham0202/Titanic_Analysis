# %% [markdown]
# # Titanic Dataset: Exploratory Data Analysis¶

# %% [markdown]
# In this notebook, we're going to analyse the famous Titanic dataset from Kaggle. The dataset is meant for supervised machine learning, but we're only going to do some exploratory analysis at this stage.
#
# We'll try to answer the following questions:
#
# Who were the passengers on the Titanic? (age, gender, class.. etc)
# What deck were the passengers on and how does that relate to their class?
# Those passanger who were having sibling/spouce and survived
# Those passanger who were having sibling/spouce and Not survived
# Those passanger who were not having sibling/spouce and survived>

# %%
import pandas as pd

# %%
df=pd.read_csv("f:/dataset/analysis/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby(by=["Survived","gender"]).Survived.count()
# Out:
# Survived  gender
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
df.pivot_table(index=["Survived","gender"],aggfunc="count")
# Out:
#                  Age  Cabin  Embarked  Fare  Name  Parch  PassengerId  Pclass  \
# Survived gender
# 0        female   64      6        81    81    81     81           81      81
#          male    360     62       468   468   468    468          468     468
# 1        female  197     91       231   233   233    233          233     233
#          male     93     45       109   109   109    109          109     109
#
#                  SibSp  Ticket
# Survived gender
# 0        female     81      81
#          male      468     468
# 1        female    233     233
#          male      109     109

# %%
x22=df[(df.SibSp==1) & (df.Survived==1)].Survived.count()
print("Those passanger who were having sibling/spouce and survived:",x22)
y22=df[(df.SibSp==1) & (df.Survived==0)].Survived.count()
print("Those passanger who were having sibling/spouce and Not survived:",y22)
z22=df[(df.SibSp==0) & (df.Survived==1)].Survived.count()
print("Those passanger who were not having sibling/spouce and survived:",z22)
# Out:
# Those passanger who were having sibling/spouce and survived: 112
# Those passanger who were having sibling/spouce and Not survived: 97
# Those passanger who were not having sibling/spouce and survived: 210

# %%
pd.get_dummies(df.gender)
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
df['gender']=df['gender'].map({'male':0,'female':1})
df.fillna({'Cabin':"C88","Age":20})
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib as mt
import matplotlib.pyplot as plt

# %%
plt.hist(x=df.Age,edgecolor="black")
plt.show()
